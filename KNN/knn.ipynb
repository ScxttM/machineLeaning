# %%
import pandas as pd
import numpy as np

# %%
trainingjcd=[]
trainingtamura=[]
trainingcolor=[]
testjcd=[]
testtamura=[]
testcolor=[]
for i in range(100):
    if i<75:
      df = pd.read_csv("./T6/dyed-lifted-polyps/"+str(i+1)+".features", sep=" ", header=None)
      dc = pd.read_csv("./T6/normal-cecum/"+str(i+1)+".features", sep=" ", header=None)
      dv = pd.read_csv("./T6/retroflex-stomach/"+str(i+1)+".features", sep=" ", header=None)
      linea = df[0][0]
      datos= np.array(df[0][0].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=1.0
      trainingjcd.append(datos)
      linea = dc[0][0]
      datos= np.array(dc[0][0].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=2.0
      trainingjcd.append(datos)
      linea = dv[0][0]
      datos= np.array(dv[0][0].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=3.0
      trainingjcd.append(datos)

      linea = df[0][1]
      datos= np.array(df[0][1].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=1.0
      trainingtamura.append(datos)
      linea = dc[0][1]
      datos= np.array(dc[0][1].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=2.0
      trainingtamura.append(datos)
      linea = dv[0][1]
      datos= np.array(dv[0][1].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=3.0
      trainingtamura.append(datos)

      linea = df[0][2] 
      datos= np.array(df[0][2].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=1.0
      trainingcolor.append(datos)
      linea = dc[0][2]
      datos= np.array(dc[0][2].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=2.0
      trainingcolor.append(datos)
      linea = dv[0][2]
      datos= np.array(dv[0][2].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=3.0
      trainingcolor.append(datos)

    else:
      df = pd.read_csv("./T6/dyed-lifted-polyps/"+str(i+1)+".features", sep=" ", header=None)
      dc = pd.read_csv("./T6/normal-cecum/"+str(i+1)+".features", sep=" ", header=None)
      dv = pd.read_csv("./T6/retroflex-stomach/"+str(i+1)+".features", sep=" ", header=None)
      linea = df[0][0]
      datos= np.array(df[0][0].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=1.0
      testjcd.append(datos)
      linea = dc[0][0]
      datos= np.array(dc[0][0].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=2.0
      testjcd.append(datos)
      linea = dv[0][0]
      datos= np.array(dv[0][0].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=3.0
      testjcd.append(datos)

      linea = df[0][1]
      datos= np.array(df[0][1].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=1.0
      testtamura.append(datos)
      linea = dc[0][1]
      datos= np.array(dc[0][1].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=2.0
      testtamura.append(datos)
      linea = dv[0][1]
      datos= np.array(dv[0][1].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=3.0
      testtamura.append(datos)

      linea = df[0][2] 
      datos= np.array(df[0][2].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=1.0
      testcolor.append(datos)
      linea = dc[0][2]
      datos= np.array(dc[0][2].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=2.0
      testcolor.append(datos)
      linea = dv[0][2]
      datos= np.array(dv[0][2].split(":")[1].rstrip().split(",")).astype(float)
      datos[-1]=3.0
      testcolor.append(datos)

print(len(trainingjcd))
print(len(trainingtamura))
print(len(trainingcolor))
print(len(testjcd))
print(len(testtamura))
print(len(testcolor))
# Out:
# 225
# 225
# 225
# 75
# 75
# 75

# %%
from collections import Counter
marker=0
result=0
kn3=[]
for test in testjcd:
  distancias = []
  for train in trainingjcd:
    distancias.append(np.sqrt(np.dot(test,train)))
  aux = []
  for i in range(5):
    min_value = min(distancias)
    aux.append(trainingjcd[distancias.index(min_value)][-1])
    kn3.append(aux)
    del distancias[distancias.index(min_value)]
print(kn3)
print(len(kn3))
for test in testjcd:
  for i in range(5):
    result = Counter(kn3[test][i])
    print(result)
